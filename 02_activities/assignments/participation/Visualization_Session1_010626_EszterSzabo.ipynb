# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5,3)) # two objects created, plt package, to generate the axes
# figsize in inches 
ax.scatter(x,y) # apply the data to the axes

# %%
fig, ax = plt.subplots(figsize=(5,3)) 
ax.bar(x,y) # bar graph
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5,3)) 
ax.plot(x,y) # line plot graph

# %%
fig, ax = plt.subplots(figsize=(5,3)) 
ax.hist(y) # histogram graph
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout() # adjusting the margins

# %%
# Modifying labels and titles (aesthetics)
# by using dictionaries
font1 = {'family': 'sans-serif', 'color': 'blue', 'size':20}
font2 = {'family': 'monospace', 'color': 'green', 'size':14}

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1, loc = 'left') # loc is used to align the titles/labels (left, right, center)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
# Modifying data points
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y, marker = '*', color = 'indigo')
fig.show() # optional, it is automatic in Jupiter, but in a python doc, you need this to show the graph
# Out:
# C:\Users\melit\AppData\Local\Temp\ipykernel_23360\4159566115.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show() # optional, it is automatic in Jupiter, but in a python doc, you need this to show the graph

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,
        y,
        marker = '*',
        color = 'indigo',
        linestyle = '--', # connecting the data points
        linewidth = 2) # width of the line
fig.show()
# Out:
# C:\Users\melit\AppData\Local\Temp\ipykernel_23360\502193557.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,
        y,
        marker = '*',
        color = 'indigo',
        linestyle = '--', 
        linewidth = 2,
        markersize = 14, # size of the data point
        markeredgecolor = '#fa9359', # edge of the data point marker
        markerfacecolor = '#000000') # fill of the marker
fig.show()
# Out:
# C:\Users\melit\AppData\Local\Temp\ipykernel_23360\2430364525.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.grid(axis='y', color='blue',linestyle='-.') # adding grid
ax.plot(x,y,marker='*',markersize=12,color='#7425b9',linestyle='--',linewidth=2,markeredgecolor='#fa9359',markerfacecolor='#000000')
